# %% [markdown]
# # IEEE-CIS Fraud Detection
# ## Preprocessing train_identity.csv, DeviceType
# *Visit [kaggle](https://www.kaggle.com/c/ieee-fraud-detection) for competition details*
#
# **Authored by Soyoung Kang**

# %%
import pandas as pd
import pandas_profiling as pp
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
# Load train and test data.

train_ = pd.read_csv('../ieee-fraud-detection/given/train_identity.csv', engine = 'python')
test_= pd.read_csv('../ieee-fraud-detection/given/test_identity.csv', engine = 'python')

# %%
# Retrieve necessary columns.

train = train_[['TransactionID', 'DeviceType', 'DeviceInfo']]
test = test_[['TransactionID', 'DeviceType', 'DeviceInfo']]

# %%
train.shape
# Out:
# (144233, 3)

# %%
train.isnull().sum()
# Out:
# TransactionID        0
# DeviceType        3423
# DeviceInfo       25567
# dtype: int64

# %%
train.groupby('DeviceType')['TransactionID'].count()
# Out:
# DeviceType
# desktop    85165
# missing     3423
# mobile     55645
# Name: TransactionID, dtype: int64

# %%
train['DeviceType'].fillna('missing', inplace = True)
test['DeviceType'].fillna('missing', inplace = True)

# %% [markdown]
# # Dummify DeviceType

# %%
train_dum = pd.get_dummies(data = train, columns = ['DeviceType'])
test_dum = pd.get_dummies(data = test, columns = ['DeviceType'])

# %%
test_dum.head()
# Out:
#    TransactionID                   DeviceInfo  DeviceType_desktop  \
# 0        3663586  MYA-L13 Build/HUAWEIMYA-L13                   0
# 1        3663588         LGLS676 Build/MXB48T                   0
# 2        3663597                  Trident/7.0                   1
# 3        3663601  MYA-L13 Build/HUAWEIMYA-L13                   0
# 4        3663602         SM-G9650 Build/R16NW                   0
#
#    DeviceType_missing  DeviceType_mobile
# 0                   0                  1
# 1                   0                  1
# 2                   0                  0
# 3                   0                  1
# 4                   0                  1

# %%
train_dum.to_csv('train_deviceType.csv', encoding = 'utf8')
test_dum.to_csv('test_deviceType.csv', encoding = 'utf8')

# %% [markdown]
# # DeviceInfo (Deprecated)

# %%
train_dum.head()
# Out:
#    TransactionID                     DeviceInfo  DeviceType_desktop  \
# 0        2987004  SAMSUNG SM-G892A Build/NRD90M                   0
# 1        2987008                     iOS Device                   0
# 2        2987010                        Windows                   1
# 3        2987011                            NaN                   1
# 4        2987016                          MacOS                   1
#
#    DeviceType_missing  DeviceType_mobile
# 0                   0                  1
# 1                   0                  1
# 2                   0                  0
# 3                   0                  0
# 4                   0                  0

# %%
list(test.DeviceInfo.unique())
# Out:
# ['MYA-L13 Build/HUAWEIMYA-L13',
#  'LGLS676 Build/MXB48T',
#  'Trident/7.0',
#  'SM-G9650 Build/R16NW',
#  'iOS Device',
#  'Windows',
#  'MacOS',
#  nan,
#  'RNE-L03 Build/HUAWEIRNE-L03',
#  'MotoE2(4G-LTE',
#  'Lenovo K33b36 Build/NRD90N',
#  'Lenovo PB1-750M Build/S100',
#  'HUAWEI CUN-L03 Build/HUAWEICUN-L03',
#  'SM-G610M Build/NRD90M',
#  'KFGIWI Build/LVY48F',
#  'Moto E (4) Plus Build/NMA26.42-152',
#  'SAMSUNG SM-A310F Build/NRD90M',
#  'GT-I9060M Build/KTU84P',
#  'SM-G610M Build/MMB29K',
#  'Power_2',
#  'Redmi 4X Build/N2G47H',
#  'SM-G920V Build/NRD90M',
#  'Z957',
#  'rv:60.0',
#  'SAMSUNG SM-G892A Build/R16NW',
#  'SAMSUNG SM-J701M Build/NRD90M',
#  '5049W Build/NRD90M',
#  'SAMSUNG',
#  '8050G Build/LMY47I',
#  'SM-G928V Build/NRD90M',
#  'SAMSUNG SM-G950U Build/R16NW',
#  'TA-1025 Build/OPR1.170623.026',
#  'SM-G930T Build/NRD90M',
#  'SM-J730GM Build/NRD90M',
#  'HUAWEI TAG-L13 Build/HUAWEITAG-L13',
#  'Hisense L675 PRO Build/NRD90M',
#  'SM-A310M Build/NRD90M',
#  'Hisense F23 Build/NRD90M',
#  'rv:61.0',
#  'rv:48.0',
#  'rv:11.0',
#  'SM-G925V Build/NRD90M',
#  'XT1710-02 Build/NDSS26.118-23-19-6',
#  'SM-G955U Build/R16NW',
#  'Android 4.4.2',
#  'SAMSUNG SM-A520F Build/R16NW',
#  'Pixel',
#  'HUAWEI VNS-L53 Build/HUAWEIVNS-L53',
#  'HUAWEI',
#  'SM-G532M Build/MMB29T',
#  'SM-G950U Build/R16NW',
#  'P008 Build/NRD90M',
#  'SM-G920F Build/NRD90M',
#  'SM-J700M Build/LMY48B',
#  'SM-N900W8 Build/LRX21V',
#  'Moto E (4) Build/NMA26.42-69',
#  'SAMSUNG SM-G925I Build/NRD90M',
#  'SAMSUNG SM-G390F Build/NRD90M',
#  'CRO-L03 Build/HUAWEICRO-L03',
#  'A7',
#  'Moto G (5) Build/NPPS25.137-15-11',
#  'Lenovo',
#  'ASUS_X008D Build/NRD90M',
#  'SM-A520F Build/NRD90M',
#  'Moto G (4) Build/NPJ25.93-14.7',
#  'SAMSUNG SM-G965F Build/R16NW',
#  'SM-G925F Build/NRD90M',
#  'Ilium X710 Build/MRA58K',
#  'SM-J510MN Build/MMB29M',
#  'G3313 Build/43.0.A.5.79',
#  'RCT6873W42M_F7',
#  'Moto G (5) Plus Build/NPN25.137-92',
#  'XT1053 Build/LPAS23.12-21.7-1',
#  'SM-T350 Build/NMF26X',
#  'WAS-LX3 Build/HUAWEIWAS-LX3',
#  '5054S Build/LMY47V',
#  'LG-D693n Build/LRX22G',
#  'ANE-LX3 Build/HUAWEIANE-LX3',
#  'SAMSUNG SM-A310M Build/LMY47X',
#  'SM-P580 Build/NRD90M',
#  'VS986 Build/MRA58K',
#  'SGH-I337M Build/LRX22C',
#  'SM-J701M Build/NRD90M',
#  'MotoG3 Build/MPI24.65-25.1',
#  'F8332',
#  'Mi',
#  'KFDOWI Build/LVY48F',
#  'rv:59.0',
#  'SAMSUNG SM-G950F Build/R16NW',
#  'VS987 Build/NRD90U',
#  'SM-G950F Build/R16NW',
#  'SM-J700M Build/MMB29K',
#  'SAMSUNG SM-G955U Build/R16NW',
#  'HUAWEI G7-L03 Build/HuaweiG7-L03',
#  'MI MAX 2 Build/NMF26F',
#  'SM-G955F Build/R16NW',
#  'S.N.O.W.4',
#  'G3121 Build/48.1.A.2.21',
#  'XT1650 Build/NCLS26.118-23-13-6-5',
#  'SM-J120H Build/LMY47V',
#  'Z981 Build/MMB29M',
#  'Blade A465 Build/LMY47D',
#  'SM-J327P Build/MMB29M',
#  'LG-M153 Build/MXB48T',
#  'GT-I9301I',
#  'F3213 Build/36.1.A.1.86',
#  'SM-G965U Build/R16NW',
#  'SAMSUNG SM-N950U Build/R16NW',
#  'Shift Build/LMY47I',
#  'MI',
#  'SAMSUNG SM-G960U Build/R16NW',
#  'G8341',
#  'SM-J530GM Build/NRD90M',
#  'SM-T560NU Build/NMF26X',
#  'moto g(6) play Build/OPP27.61-14-4',
#  'i50F Build/NRD90M',
#  'G3223 Build/42.0.A.4.167',
#  'VTR-L09 Build/HUAWEIVTR-L09',
#  'LG-X180g Build/LMY47I',
#  'SM-G570M Build/MMB29K',
#  'SM-A510M Build/NRD90M',
#  'ALCATEL ONE TOUCH 7042A Build/JDQ39',
#  'BAC-L03 Build/HUAWEIBAC-L03',
#  'SM-G900F Build/KOT49H',
#  'HUAWEI VNS-L21 Build/HUAWEIVNS-L21',
#  'Hisense F24 Build/NRD90M',
#  'rv:52.0',
#  'LG-H542 Build/MRA58K',
#  'SM-G950U1 Build/R16NW',
#  'Linux x86_64',
#  'Moto C Build/NRD90M.057',
#  'SM-G935F Build/NRD90M',
#  'SAMSUNG SM-G610M Build/MMB29K',
#  'SAMSUNG SM-G532M Build/MMB29T',
#  'LG-X210 Build/LMY47I',
#  'SM-G570M Build/NRD90M',
#  'SM-G935V Build/R16NW',
#  'Moto',
#  'SM-J327T1 Build/NRD90M',
#  'M4 SS4456 Build/LMY47V',
#  'LG-D680 Build/KOT49I',
#  'G3313 Build/43.0.A.7.25',
#  'XT1575 Build/NPHS25.200-23-1',
#  'SM-G935F Build/MMB29K',
#  'SM-G800M Build/KOT49H',
#  'Moto G (4) Build/NPJS25.93-14-18',
#  'F3313 Build/37.0.A.2.248',
#  'SM-G920P Build/NRD90M',
#  'KFTBWI Build/LVY48F',
#  'rv:53.0',
#  'SM-G930V Build/R16NW',
#  'D5306 Build/19.4.A.0.182',
#  'SM-G900V Build/MMB29M',
#  'SM-G930P Build/R16NW',
#  'Moto G (4) Build/NPJS25.93-14-8.1-9',
#  'LM-Q710(FGN',
#  'HTC Desire 10 lifestyle Build/MMB29M',
#  'SAMSUNG SM-J700M Build/MMB29K',
#  'Build/OPM1.171019.011',
#  'SM-J111M Build/LMY47V',
#  'SAMSUNG SM-G950U1 Build/R16NW',
#  'RCT6513W87 Build/MRA58K',
#  'PRA-LX3 Build/HUAWEIPRA-LX3',
#  'SM-T820',
#  'SM-J200M Build/LMY47X',
#  'MotoG3 Build/MPIS24.65-33.1-2-16',
#  'SM-J710MN Build/NRD90M',
#  'SM-N950U Build/R16NW',
#  'HUAWEI VNS-L23 Build/HUAWEIVNS-L23',
#  'RNE-L23 Build/HUAWEIRNE-L23',
#  'moto e5 Build/OPP27.91-25',
#  'LG-M250 Build/NRD90U',
#  'Moto G (5) Build/NPP25.137-93',
#  'ALE-L23 Build/HuaweiALE-L23',
#  'SAMSUNG SM-N900W8 Build/LRX21V',
#  'SAMSUNG SM-G965U Build/R16NW',
#  'SM-T280 Build/LMY47V',
#  'SAMSUNG SM-G925F Build/NRD90M',
#  'Lenovo TB2-X30F Build/LenovoTB2-X30F',
#  'SAMSUNG SM-G531H Build/LMY48B',
#  'BND-L24',
#  'SM-T350 Build/MMB29M',
#  'Blade A510 Build/MRA58K',
#  'SM-G900M Build/LRX21T',
#  'SAMSUNG SM-G920F Build/NRD90M',
#  'Android 8.0.0',
#  'TRT-L53 Build/HUAWEITRT-L53',
#  'LG-H840 Build/NRD90U',
#  '5011A Build/NRD90M',
#  'Lenovo YT3-850F Build/MMB29M',
#  'LG-X230 Build/MRA58K',
#  '4047A Build/NRD90M',
#  'LG-K500 Build/MMB29M',
#  'Blade A475 Build/LMY47D',
#  'SM-G928T Build/NRD90M',
#  'SAMSUNG-SM-G930A Build/R16NW',
#  'SM-G610F Build/NRD90M',
#  'TU20402-58',
#  'ALP-L09 Build/HUAWEIALP-L09S',
#  'SAMSUNG SM-G955F Build/R16NW',
#  'E5506 Build/29.2.A.0.166',
#  'LG-H830 Build/NRD90U',
#  'Ilium X520 Build/NRD90M',
#  'Z831',
#  'SM-G9650',
#  'Nexus',
#  '6045I Build/LRX22G',
#  'TA-1028 Build/O00623',
#  'SM-G531H Build/LMY48B',
#  'Moto Z2 Play Build/NPSS26.118-19-14',
#  'F8331 Build/41.2.A.7.76',
#  'Moto C Build/NRD90M.063',
#  'FIG-LX3 Build/HUAWEIFIG-LX3',
#  'LG-K410 Build/LRX22G',
#  'E6603 Build/32.4.A.1.54',
#  'LGMS428',
#  'Alumini3 Build/MRA58K',
#  'SM-J250M Build/NMF26X',
#  'LG-M320 Build/NRD90U',
#  'SAMSUNG SM-J510MN Build/MMB29M',
#  'SM-G935P',
#  'SM-A720F Build/NRD90M',
#  'SM-T550 Build/NMF26X',
#  'LG-H815 Build/MRA58K',
#  'Moto G (5) Build/NPP25.137-82',
#  'SAMSUNG SM-A730F Build/NMF26X',
#  'ZEI403',
#  'Ilium L610 Build/MRA58K',
#  'Moto G (5) Build/NPPS25.137-93-12',
#  '5051A Build/MMB29M',
#  'F3113 Build/33.3.A.1.97',
#  'SM-G960U Build/R16NW',
#  'XT1032 Build/KXB20.9-1.10-1.24-1.1',
#  'LG-M700 Build/NMF26X',
#  'rv:41.0',
#  'SM-G930F Build/NRD90M',
#  'SM-N950U1 Build/R16NW',
#  'HTC_One_M8/4.28.502.2',
#  'SM-J730G Build/NRD90M',
#  'Hisense E51 Build/LMY47V',
#  'Moto G Play Build/MPIS24.241-15.3-7',
#  'XT1635-02 Build/NPN26.118-22-2',
#  'Pixel 2 Build/OPM2.171026.006.C1',
#  'SAMSUNG SM-G930F Build/NRD90M',
#  'PRA-LX2',
#  'HUAWEI NXT-L09 Build/HUAWEINXT-L09',
#  'rv:49.0',
#  '5025G Build/LMY47I',
#  'SLA-L03 Build/HUAWEISLA-L03',
#  'SM-G935F Build/R16NW',
#  'SM-P550 Build/NMF26X',
#  'HTC',
#  'rv:58.0',
#  'SAMSUNG SM-G935P Build/NRD90M',
#  'BBB100-2',
#  'Moto C Plus Build/NRD90M.05.034',
#  'Moto E (4) Build/NMA26.42-19',
#  'LG-K428 Build/NRD90U',
#  'Ilium L1120 Build/NRD90M',
#  'SM-G950',
#  'WAS-LX1 Build/HUAWEIWAS-LX1',
#  'Moto E (4) Plus Build/NMA26.42-142',
#  'SM-N920V Build/NRD90M',
#  'M4',
#  'EML-L09 Build/HUAWEIEML-L09',
#  'Nexus 5X Build/N2G48C',
#  'CHC-U03 Build/HuaweiCHC-U03',
#  'BLA-L09',
#  'Hisense F32 Build/NMF26F',
#  'SAMSUNG SM-G930F Build/R16NW',
#  'P5006A Build/NRD90M',
#  'LG-K220 Build/MXB48T',
#  'SM-T560 Build/KTU84P',
#  'SAMSUNG SM-G935F Build/NRD90M',
#  'G3123 Build/40.0.A.6.189',
#  'Moto E (4) Plus Build/NMA26.42-69',
#  'Hisense F8 MINI Build/NRD90M',
#  'M4 SS4451 Build/LMY47D',
#  'BLADE V8 SE Build/NRD90M',
#  'Ilium LT520 Build/NRD90M',
#  'E5306',
#  'CAM-L03 Build/HUAWEICAM-L03',
#  'ASUS_X00HD Build/NMF26F',
#  'SM-J500M Build/MMB29M',
#  'SM-T360',
#  'SM-A520F Build/R16NW',
#  'TA-1027 Build/OPR1.170623.026',
#  'T09',
#  'Studio',
#  '5026A Build/NRD90M',
#  'SM-A310F Build/MMB29K',
#  'SAMSUNG SM-G530H Build/LRX22G',
#  'REVVLPLUS',
#  'FEVER',
#  'SM-A530F Build/NMF26X',
#  'ONE A2003 Build/MMB29M',
#  'Vivo',
#  'SM-T710 Build/NRD90M',
#  'Aquaris_M4.5',
#  'SAMSUNG SM-J327P Build/MMB29M',
#  'Mi A1 Build/OPR1.170623.026',
#  'SM-T113NU Build/KTU84P',
#  'Moto X Play Build/NPD26.48-24-1',
#  'A1601 Build/LMY47I',
#  'Moto G (4) Build/NPJS25.93-14-15',
#  'SM-J727V Build/NRD90M',
#  'KFFOWI Build/LVY48F',
#  'LG-M710 Build/NRD90U',
#  'iris',
#  'XT1650',
#  'Redmi Note 3 Build/MMB29M',
#  'A0001 Build/MHC19Q',
#  'SM-J120FN Build/LMY47X',
#  'Ilium X510 Build/MRA58K',
#  'PRA-LX1 Build/HUAWEIPRA-LX1',
#  'moto',
#  'Blade L5 Build/LMY47I',
#  'SAMSUNG SM-G9600 Build/R16NW',
#  'SM-G903F Build/MMB29K',
#  'SM-J510FN Build/NMF26X',
#  'moto x4 Build/OPWS27.57-40-6',
#  'LG-K530 Build/MMB29M',
#  'SAMSUNG SM-A520F Build/NRD90M',
#  'SM-G955U Build/NRD90M',
#  'SAMSUNG SM-J530GM Build/NRD90M',
#  'Build/OPR1.170623.032',
#  'COL-L29',
#  'Gravity Build/NRD90M',
#  'SAMSUNG SM-A530F Build/NMF26X',
#  'ZTE BLADE V8 MINI Build/NRD90M',
#  'SAMSUNG SM-J730GM Build/NRD90M',
#  'SM-G930V Build/NRD90M',
#  'SM-N950F Build/R16NW',
#  'Lenovo PB2-650Y Build/MRA58K',
#  'Aquaris U Plus Build/NMF26F',
#  'Android 7.1.2',
#  'Moto G (4) Build/NPJS25.93-14-8.1-4',
#  'Moto G (5) Plus Build/NPN25.137-15',
#  'SM-N950U Build/NMF26X',
#  'E5823 Build/32.4.A.1.54',
#  'SM-J320M Build/LMY47V',
#  'LG-M703',
#  'AERIAL',
#  'LG-H500 Build/LRX21Y',
#  'SAMSUNG SM-G920P Build/NRD90M',
#  'Moto G (4) Build/NPJS25.93-14.7-8',
#  'GT-I9506',
#  'SM-J327V Build/NRD90M',
#  'BND-L21 Build/HONORBND-L21',
#  'XT1650 Build/NPLS26.118-20-5-3',
#  'SM-G930F Build/R16NW',
#  'es-mx',
#  'SAMSUNG-SM-G920A Build/MMB29K',
#  'FRD-L09 Build/HUAWEIFRD-L09',
#  'SM-G930U Build/NRD90M',
#  '5015A Build/LMY47I',
#  '5056A Build/MMB29M',
#  'LG-H650 Build/LMY47V',
#  'XT1635-02 Build/OPNS27.76-12-22-3',
#  'Nexus 6 Build/N6F27M',
#  'moto x4 Build/OPW27.57-40',
#  'R8006',
#  '4047G Build/NRD90M',
#  'Pixel 2 Build/OPM2.171026.006.G1',
#  '5010G Build/MRA58K',
#  'GLAM',
#  'SM-J700T1 Build/NMF26X',
#  'SAMSUNG-SM-G925A',
#  'Moto G (5) Build/NPP25.137-72',
#  'ATU-LX3 Build/HUAWEIATU-LX3',
#  'D2206',
#  'Android 6.0',
#  'HTC Desire 626s Build/LMY47O',
#  '8080 Build/LRX21M',
#  'BLADE A520 Build/NRD90M',
#  'SAMSUNG-SM-T817A',
#  'A37fw',
#  'SM-G920T Build/NRD90M',
#  'SAMSUNG SM-G925P Build/NRD90M',
#  '6039A Build/LRX22G',
#  'Hisense L675 Build/MRA58K',
#  'HTC Desire 650 Build/MMB29M',
#  'SAMSUNG SM-T587P Build/NRD90M',
#  'LG-H870 Build/NRD90U',
#  'Moto Z2 Play Build/NPSS26.118-19-6',
#  'SAMSUNG SM-N950F Build/NMF26X',
#  'Microsoft',
#  'SM-G386F',
#  'MI 4W Build/MMB29M',
#  'Alcatel_5098O Build/MMB29M',
#  'IdeaTab',
#  'LG-K200 Build/MXB48T',
#  'MHA-L29 Build/HUAWEIMHA-L29',
#  'LG-X220 Build/LMY47I',
#  'LG-H931 Build/OPR1.170623.026',
#  'Moto G (4) Build/NPJS25.93-14-10',
#  'LG-K580 Build/MRA58K',
#  'XT1635-01',
#  'Lenovo-A6020l36 Build/LMY47V',
#  'SM-A500M Build/KTU84P',
#  'Blade L2 Plus Build/KOT49H',
#  'SM-G925T Build/NRD90M',
#  'SM-G530H Build/KTU84P',
#  'SAMSUNG SM-G930A Build/R16NW',
#  'SAMSUNG-SM-J120A',
#  'BLADE V8 Build/NRD90M',
#  'SM-J400M Build/R16NW',
#  'Redmi Note 4 Build/NRD90M',
#  'moto g(6) plus Build/OPWS27.113-25-4',
#  'Dash',
#  'LGMP260 Build/NRD90U',
#  'SAMSUNG SM-G920I Build/NRD90M',
#  'Y635-L03 Build/HuaweiY635-L03',
#  'A37f',
#  'rv:62.0',
#  'SAMSUNG SM-G950F Build/NRD90M',
#  'SM-G930T Build/R16NW',
#  'SM-J106B',
#  'SAMSUNG-SM-G900A Build/KOT49H',
#  'SAMSUNG SM-G570M Build/MMB29K',
#  'FRD-L14 Build/HUAWEIFRD-L14',
#  'Pixel Build/OPM4.171019.021.P1',
#  'F5121',
#  'SM-A300H Build/LRX22G',
#  'SM-A320Y Build/NRD90M',
#  'SAMSUNG SM-G925T Build/NRD90M',
#  'WAS-LX1A Build/HUAWEIWAS-LX1A',
#  'T1-A21w',
#  'SM-N915T',
#  'SM-A320FL Build/R16NW',
#  'es-us',
#  'Pixel XL Build/OPM4.171019.021.P1',
#  'XT1032 Build/LPBS23.13-56-2',
#  'SM-G892U Build/R16NW',
#  'LG-H320 Build/LRX21Y',
#  'SAMSUNG-SM-G935A',
#  'SM-G355M Build/KOT49H',
#  'LG-K373',
#  'Pixel 2 XL Build/OPM2.171026.006.H1',
#  'HTC One A9s Build/MRA58K',
#  'moto x4 Build/NPW26.83-42',
#  'SM-J500M Build/LMY48B',
#  'G8141',
#  'AERIAL Build/NRD90M',
#  'ZTE BLADE A512 Build/MMB29M',
#  'Moto G (5) Plus Build/NPN25.137-82',
#  'SM-G950U Build/NRD90M',
#  'KFMEWI',
#  'SM-G925I Build/NRD90M',
#  'Ilium X210 Build/LMY47I',
#  'EML-L29 Build/HUAWEIEML-L29',
#  'Blade V6 Plus Build/MRA58K',
#  'Moto G (5S',
#  'Redmi Note 5A Build/N2G47H',
#  'SM-G928G Build/MMB29K',
#  'SM-J727T1 Build/NRD90M',
#  'Blade V580 Build/LMY47D',
#  'SAMSUNG SM-G925P Build/MMB29K',
#  'VS501 Build/NRD90U',
#  'XT1580 Build/NPKS25.200-17-8',
#  'Redmi 3S Build/MMB29M',
#  'Moto G (5) Plus Build/NPNS25.137-92-10',
#  'SAMSUNG SM-G935T Build/R16NW',
#  'rv:42.0',
#  'VS995 Build/NRD90M',
#  'SM-J510H',
#  'SM-G550T1 Build/MMB29K',
#  'SM-G955F Build/NRD90M',
#  'MDDRJS',
#  'SAMSUNG SM-J727T1 Build/NRD90M',
#  'Moto G Play Build/NJH47F',
#  'AX681',
#  'SAMSUNG SM-N920V Build/NRD90M',
#  'BLU LIFE XL Build/L050U',
#  'LS5',
#  'SM-J500H',
#  'SM-G930T1',
#  'SM-N910F Build/MMB29M',
#  'rv:57.0',
#  'BLADE L7 Build/MRA58K',
#  'KFAUWI Build/LVY48F',
#  'iris 870 Build/MRA58K',
#  'ZTE BLADE A0620 Build/NMF26F',
#  'SM-G892A',
#  'Blade V6 Build/LRX22G',
#  'SM-N900V Build/LRX21V',
#  'ALCATEL ONE TOUCH 7047A Build/JDQ39',
#  'SM-N910C Build/MMB29K',
#  'HTC Desire 530 Build/MMB29M',
#  'SM-T813 Build/NRD90M',
#  'Lenovo K33b36 Build/MMB29M',
#  'SM-N920C Build/NRD90M',
#  'SAMSUNG SM-A510M Build/MMB29K',
#  'LG-K210',
#  'Ilium L910 Build/MRA58K',
#  'HUAWEI CAN-L11 Build/HUAWEICAN-L11',
#  'Redmi Note 4X Build/MRA58K',
#  'LG-TP450 Build/NRD90U',
#  'EVA-L09 Build/HUAWEIEVA-L09',
#  'SAMSUNG SM-J327T1 Build/NRD90M',
#  'SAMSUNG-SM-G891A Build/R16NW',
#  'LM-X210 Build/N2G47H',
#  'SM-A310M Build/LMY47X',
#  'SM-N900T Build/LRX21V',
#  'SM-S727VL Build/MMB29M',
#  'ALE-L21 Build/HuaweiALE-L21',
#  'SAMSUNG SM-A310F/A310FXXU4CRB1 Build/NRD90M',
#  'SM-G930VL Build/NRD90M',
#  'Moto G (5) Plus Build/NPNS25.137-92-14',
#  'GT-N5110 Build/JDQ39',
#  'RNE-L22 Build/HUAWEIRNE-L22',
#  'Moto Z (2',
#  'XT1580 Build/NPKS25.200-12-9',
#  'Moto E (4) Build/NCQ26.69-56',
#  'LG-H345',
#  'SAMSUNG SM-G890A Build/NRD90M',
#  'SAMSUNG SM-G9650 Build/R16NW',
#  'E5823',
#  'moto x4 Build/OPWS27.57-40-17',
#  'YOGA',
#  'SM-G530H Build/LRX22G',
#  'D5503 Build/14.6.A.0.368',
#  'SM-G800F Build/MMB29K',
#  'SAMSUNG SM-J530F Build/NRD90M',
#  'Nexus 5 Build/M4B30Z',
#  'HUAWEI RIO-L03 Build/HUAWEIRIO-L03',
#  'Linux i686',
#  'SM-N920G Build/NRD90M',
#  'LG-D802',
#  'BLL-L23 Build/HUAWEIBLL-L23',
#  'R8106',
#  'Lenovo A6020l37 Build/LMY47V',
#  'weimei_we',
#  'HUAWEI VNS-L31 Build/HUAWEIVNS-L31',
#  'XT1254 Build/MCG24.251-5-5',
#  'LGL59BL',
#  'Moto G (5) Build/NPPS25.137-93-4',
#  'SM-G900M Build/MMB29M',
#  'SAMSUNG SM-T550 Build/NMF26X',
#  'LG-H872 Build/NRD90U',
#  'SAMSUNG SM-G960U1 Build/R16NW',
#  'BLADE A602 Build/MRA58K',
#  'BLADE V9 Build/OPR1.170623.032',
#  'HTC One A9 Build/NRD90M',
#  'SM-G960F Build/R16NW',
#  'HUAWEI GRA-L09 Build/HUAWEIGRA-L09',
#  'TA-1039 Build/OPR1.170623.026',
#  'LG-X240 Build/MRA58K',
#  'SM-A605GN Build/R16NW',
#  'M4 SS4453 Build/MMB29M',
#  'LG-D320',
#  'SM-G930P Build/NRD90M',
#  'SM-E500M Build/KTU84P',
#  'TA-1044 Build/OPR1.170623.026',
#  'SAMSUNG SM-N950N Build/R16NW',
#  'XT1585 Build/NCK25.118-10.5',
#  'LGLS675 Build/LMY47V',
#  'ENERGY',
#  'SM-T230 Build/KOT49H',
#  'VKY-L09 Build/HUAWEIVKY-L09',
#  'LG-M327 Build/NRD90U',
#  '5044A',
#  'SAMSUNG-SM-G900A Build/LMY47X',
#  'SAMSUNG-SM-G890A Build/NRD90M',
#  'HUAWEI Build/MMB28B',
#  'VIE-L09',
#  'SAMSUNG SM-J500M Build/LMY48B',
#  'H3321',
#  'ZTE',
#  'SM-N910V Build/MMB29M',
#  'SM-G935V Build/NRD90M',
#  'Moto G Play Build/NPIS26.48-43-2',
#  'iris 820 Build/MRA58K',
#  'SM-T805 Build/MMB29K',
#  'LLD-L31 Build/HONORLLD-L31',
#  'Moto G (5) Build/NPPS25.137-93-8',
#  'Blade V6 Max Build/MRA58K',
#  'HUAWEI Y625-U13 Build/HUAWEIY625-U13',
#  '5080A Build/MRA58K',
#  'Tank',
#  'SAMSUNG SM-J250M Build/NMF26X',
#  'LG-X165g Build/LRX21M',
#  'moto g(6) Build/OPS27.82-72',
#  'LG-D693n',
#  'Z557BL',
#  'LGMS210 Build/NRD90U',
#  'NEM-L51 Build/HONORNEM-L51',
#  'LM-X210CM',
#  'ASUS_X00AD',
#  'XT1635-02 Build/OPN27.76-12-22',
#  'LM-X410(FG',
#  'SM-A510M Build/LMY47X',
#  'SAMSUNG SM-J320F Build/LMY47V',
#  'LG-TP260 Build/NRD90U',
#  'ATT-IE11',
#  '5085A',
#  'SAMSUNG SM-J320M Build/LMY47V',
#  'LG-K430 Build/MRA58K',
#  'G3123 Build/48.1.A.2.21',
#  'HIGHWAY',
#  'SM-T827V Build/NRD90M',
#  'SM-G900P Build/LRX21T',
#  'KFAPWI Build/KTU84M',
#  'SAMSUNG-SM-J727A Build/NRD90M',
#  'FP2',
#  'D5803',
#  'Orange_Rise_33',
#  'N9519',
#  'VS996 Build/OPR1.170623.026',
#  'H3311',
#  'MotoG3 Build/MPI24.65-33.1-2',
#  'Mi A1 Build/N2G47H',
#  'SM-G950W',
#  'es-es',
#  'S8',
#  'Mi A1 Build/OPM1.171019.026',
#  'SM-G9600 Build/R16NW',
#  'Moto E (4) Build/NMA26.42-11-3',
#  'PLK-L01 Build/HONORPLK-L01',
#  'ALP-L09 Build/HUAWEIALP-L09',
#  'LG-H872',
#  'CLT-L29 Build/HUAWEICLT-L29',
#  'LG-D331 Build/LRX22G',
#  'SM-N920T Build/NRD90M',
#  '5010S Build/MRA58K',
#  'TA-1044 Build/NMF26F',
#  'VORAGO',
#  'LG-H918 Build/NRD90M',
#  'XT1032 Build/KXB21.14-L1.40',
#  'SM-T217T',
#  'SM-P350 Build/MMB29M',
#  'SM-G900V Build/LRX21T',
#  'E5803 Build/32.4.A.1.54',
#  'AX1060',
#  'LG-D850',
#  'F3311',
#  'SM-N9005 Build/LRX21V',
#  'BKL-L09',
#  '4027A Build/KOT49H',
#  'HUAWEI LUA-U23 Build/HUAWEILUA-U23',
#  'LG-H860',
#  'SM-J737P Build/R16NW',
#  'SM-G950F Build/NRD90M',
#  'Moto Z2 Play Build/NPSS26.118-19-11',
#  '6036A Build/JLS36C',
#  'SM-G955U1 Build/R16NW',
#  'Z839',
#  'vivo',
#  'Z982 Build/NMF26V',
#  'SM-N950F Build/NMF26X',
#  'LG-K557 Build/MXB48T',
#  'SM-G900H Build/MMB29K',
#  'MotoG3 Build/MPIS24.107-55-2-17',
#  'SM-S737TL',
#  'SM-G935S',
#  'ZTE BLADE A6 Build/NMF26F',
#  'Lenovo TB-X103F Build/LenovoTB-X103F',
#  'Lenovo TB3-710F Build/LRX21M',
#  'SAMSUNG-SM-G900A Build/LRX21T',
#  'moto g(6) play Build/OPP27.91-87',
#  'TA-1039 Build/N2G47H',
#  'Aquaris',
#  'SAMSUNG-SM-G900A Build/MMB29M',
#  'SM-A500M Build/LRX22G',
#  'SM-A730F Build/NMF26X',
#  'SM-J330FN Build/NRD90M',
#  'SAMSUNG SM-A510M Build/NRD90M',
#  'Z956 Build/MMB29M',
#  'rv:51.0',
#  'SM-A710M Build/LMY47X',
#  'SM-J320FN Build/LMY47V',
#  'rv:45.0',
#  'G3313 Build/43.0.A.7.55',
#  'LG-D722',
#  'HUAWEI Y560-L03 Build/HUAWEIY560-L03',
#  'SM-G316M',
#  '5049Z',
#  'SAMSUNG SM-J700M Build/LMY48B',
#  'CUBOT_X18_Plus',
#  'GT-N5120',
#  'SM-J327W',
#  'ORION',
#  'SAMSUNG SM-A520W Build/NRD90M',
#  'LG-H930',
#  'SM-J700T Build/MMB29K',
#  'LG-V400',
#  'Moto Z2 Play Build/NPS26.118-19',
#  'SM-A300FU Build/MMB29M',
#  'rv:26.0',
#  'Moto G (5) Build/NPP25.137-38',
#  'SM-G900P Build/MMB29M',
#  'F3216',
#  'LM-X210(G',
#  'LG-D320 Build/KOT49I.V10a',
#  'SM-J600G Build/R16NW',
#  'Moto G (5) Plus Build/NPN25.137-35',
#  '5085B Build/MRA58K',
#  'LGLS775 Build/NRD90U',
#  'LG-D693n Build/KOT49I.V10a',
#  'SAMSUNG SM-N950F Build/R16NW',
#  'SAMSUNG-SM-J321AZ',
#  'Lenovo A2016b30 Build/MRA58K',
#  'SAMSUNG SM-N920T Build/NRD90M',
#  'Moto Z3 Play Build/OPW28.70-22',
#  'RAINBOW',
#  'COVET Build/NRD90M',
#  'SM-J710MN Build/MMB29K',
#  'BOIE9',
#  'SM-G925I Build/LMY47X',
#  'Ilium L620 Build/NRD90M',
#  'SAMSUNG-SM-G891A Build/NRD90M',
#  'TOMMY2',
#  'SM-G920I Build/NRD90M',
#  'LG-M400 Build/NRD90U',
#  'SM-G930U Build/R16NW',
#  'SM-J510MN Build/NMF26X',
#  'WAS-L03T Build/HUAWEIWAS-L03T',
#  'SAMSUNG-SM-N900A',
#  'SM-T355Y Build/NMF26X',
#  'Moto Z2 Play Build/NPSS26.118-19-22',
#  'XT1609 Build/NPIS26.48-38-3',
#  'SM-G965U1',
#  'BLU',
#  'NATIVO Build/NRD90M',
#  'BLA-L29 Build/HUAWEIBLA-L29S',
#  'E5606 Build/30.2.A.1.21',
#  'Miracle',
#  'LGLS991',
#  'FLA-LX3 Build/HUAWEIFLA-LX3',
#  'MYA-L11',
#  'F5321',
#  'LG-LS777 Build/NRD90U',
#  'SM-T585',
#  'SM-G928T',
#  'SAMSUNG SM-J330FN Build/NRD90M',
#  'SM-T530NU Build/LRX22G',
#  'SM-T580 Build/NRD90M',
#  'LG-H870',
#  'SAMSUNG SM-J111M Build/LMY47V',
#  'SM-G928G',
#  'SM-G935T Build/R16NW',
#  'SM-G965F Build/R16NW',
#  'SM-A300M Build/KTU84P',
#  'H3223 Build/50.1.A.10.40',
#  'SM-G928V Build/MMB29K',
#  'SAMSUNG SM-N920P Build/NRD90M',
#  'ONEPLUS A3003 Build/OPR1.170623.032',
#  'Moto C Build/NRD90M.070',
#  'G3223 Build/48.1.A.2.21',
#  'MotoG3-TE Build/MPDS24.65-33-1-30',
#  'SAMSUNG SM-G903F Build/MMB29K',
#  'SM-G928G Build/NRD90M',
#  'HTC One M9 Build/NRD90M',
#  'Gini s5Pro Build/NRD90M',
#  'SM-A720F Build/MMB29K',
#  'SM-G920R7',
#  'LM-G710',
#  'KFASWI Build/LVY48F',
#  'E2104 Build/24.0.A.5.14',
#  'LG-K550 Build/NRD90U',
#  'SAMSUNG SM-G935A Build/R16NW',
#  'EV05',
#  'SAMSUNG SM-J700T Build/NMF26X',
#  'ASUS_X00ID',
#  'SAMSUNG SM-J710MN Build/NRD90M',
#  'SM-N910T',
#  'SM-A510F Build/MMB29K',
#  'SM-J530F Build/NRD90M',
#  'LG-D855',
#  'XT1003',
#  'SM-G800F',
#  'STF-L09 Build/HUAWEISTF-L09',
#  'SAMSUNG SM-G960F Build/R16NW',
#  'FIG-LX1 Build/HUAWEIFIG-LX1',
#  'BLADE V8Q Build/N2G47H',
#  'Nokia 6.1 Build/OPR1.170623.026',
#  'SM-J110M Build/LMY48B',
#  'HTC 10 Build/OPR1.170623.027',
#  'FP1U',
#  'LDN-LX3 Build/HUAWEILDN-LX3',
#  'SM-A530F Build/R16NW',
#  'SM-G960U1',
#  'Android 5.1',
#  'Moto G Play Build/NPIS26.48-36-2',
#  'A10 Pro Build/LMY47I',
#  'LG-D852',
#  'Ilium L1000 Build/LRX22G',
#  'SAMSUNG SM-G532F Build/MMB29T',
#  'XT1064',
#  'SAMSUNG SM-J320FN Build/LMY47V',
#  'MotoG3 Build/MPIS24.65-25.1-19',
#  'XT1650 Build/OCLS27.76-69-6',
#  'Build/KOT49H',
#  'SM-T377P Build/NMF26X',
#  'SAMSUNG SM-G570M Build/NRD90M',
#  'Blade A460 Build/LMY47O',
#  'SAMSUNG SM-G930T Build/NRD90M',
#  'Hisense U963 Build/MRA58K',
#  'CLT-L09',
#  'LG-H735 Build/LMY47V',
#  'VK815',
#  'Moto G (5) Build/NPPS25.137-93-14',
#  'G8232',
#  'Hisense T963 Build/MRA58K',
#  'RIM',
#  'G3112',
#  'N9560 Build/NMF26F',
#  'PH-1',
#  'Redmi',
#  'ONEPLUS A5010 Build/OPM1.171019.011',
#  'moto e5 Build/OPP27.91-72',
#  'SAMSUNG-SM-J320A Build/NMF26X',
#  'Redmi Note 3 Build/NMF26Q',
#  'SAMSUNG SM-J600G Build/R16NW',
#  'SAMSUNG SM-G900M Build/LRX21T',
#  'P00I',
#  'SM-N950W',
#  'SM-J701MT',
#  'ALCATEL ONE TOUCH 5036A Build/JDQ39',
#  'LG-LS997 Build/OPR1.170623.032',
#  'Moto G (5) Plus Build/NPNS25.137-93-14',
#  'G8142',
#  'SAMSUNG SM-A320Y Build/NRD90M',
#  'R7plusf',
#  'SM-G357FZ',
#  'F3112',
#  'SM-A320FL Build/MMB29K',
#  'DUO',
#  'E2306 Build/26.1.A.3.111',
#  'XT1563 Build/MPDS24.107-52-5',
#  'SM-A520W Build/R16NW',
#  'SM-P555M',
#  'Z730',
#  'Moto Z2 Play Build/OPS27.76-12-25',
#  'S57 Build/KTU84P',
#  'SAMSUNG SM-A320FL Build/R16NW',
#  'P5526A Build/NRD90M',
#  'moto x4 Build/OPWS27.57-40-14',
#  'SM-J105B Build/LMY47V',
#  'F3113',
#  'SM-A510F',
#  'SAMSUNG SM-G950U Build/NRD90M',
#  'LG-V410',
#  'ONEPLUS A5000 Build/OPM1.171019.011',
#  '9203A Build/MRA58K',
#  'Android',
#  'Blade',
#  'Redmi Note 5 Build/OPM1.171019.011',
#  'LGMS550 Build/NRD90U',
#  'RCT6303W87M7 Build/MRA58K',
#  'SM-J730F',
#  'Hisense F20 Build/MMB29M',
#  'ONE',
#  'STV100-3',
#  'DRA-LX3 Build/HUAWEIDRA-LX3',
#  'Aquaris V Build/N2G47H',
#  'VKY-L29',
#  'GT-I8190L Build/JZO54K',
#  'Moto Z2 Play Build/OPSS27.76-12-25-3',
#  'Note8',
#  'F5321 Build/34.3.A.0.238',
#  'XT1562',
#  'LG-H650 Build/MRA58K',
#  'SM-G900F Build/MMB29M',
#  'SAMSUNG-SM-J320AZ Build/MMB29K',
#  'M4 SS4457-R Build/NRD90M',
#  'CAM-L21',
#  'SM-T810 Build/NRD90M',
#  'Energy X 2 Build/E050L',
#  'SM-A510F Build/NRD90M',
#  'SM-G900W8',
#  'Ilium L950 Build/KTU84P',
#  'BLADE V7 Build/MRA58K',
#  'SM-T320 Build/KOT49H',
#  'rv:56.0',
#  'MHA-L09 Build/HUAWEIMHA-L09',
#  'Lenovo YT3-X50F Build/MMB29M',
#  'Nokia',
#  'BLN-L21 Build/HONORBLN-L21',
#  'rv:60.1.0',
#  'TA-1027 Build/N2G47H',
#  'M4 SS4458 Build/MMB29M',
#  'Android 7.0',
#  '5012G Build/MRA58K',
#  'SAMSUNG SM-G930T Build/R16NW',
#  'ANE-LX1 Build/HUAWEIANE-LX1',
#  'HTC Desire 510 Build/KOT49H',
#  'SH-01K',
#  'Grand',
#  'RCT6973W43MD',
#  'LG-M200 Build/NRD90U',
#  'LG-V410/V41020e',
#  'E5306 Build/27.3.A.0.129',
#  'Neffos X1 Max Build/NRD90M',
#  'SAMSUNG SM-G935T Build/NRD90M',
#  'VS988 Build/OPR1.170623.032',
#  'SAMSUNG SM-N900T Build/LRX21V',
#  'LG-M430 Build/NRD90U',
#  'LM-X212(G',
#  'Redmi 5 Plus Build/N2G47H',
#  'LG-H955',
#  'SM-N900P Build/LRX21V',
#  'Alcatel',
#  'rv:55.0',
#  'DLI-L22 Build/HONORDLI-L22',
#  'SM-J320V Build/NMF26X',
#  'SM-G935F',
#  'SAMSUNG SM-G530T Build/LMY47X',
#  'Life',
#  'KFSUWI Build/LVY48F',
#  'LGMP450 Build/NRD90U',
#  'SM-G935P Build/NRD90M',
#  'rv:47.0',
#  'SM-A310F Build/NRD90M',
#  'moto g(6) Build/OPS27.82-87',
#  'SAMSUNG SM-T710 Build/NRD90M',
#  'SAMSUNG SM-J400M Build/R16NW',
#  'BLA-A09 Build/HUAWEIBLA-A09',
#  'C1904',
#  'Pixel 2 Build/PPR1.180610.009',
#  'ZA509',
#  'LGLS751',
#  'LG-H871',
#  'Moto E (4) Plus Build/NMA26.42-11-3',
#  'SAMSUNG-SM-G935A Build/NRD90M',
#  'SAMSUNG-SM-J727AZ',
#  'U2',
#  'SM-G928F',
#  'ONE A2005 Build/MMB29M',
#  'XT1063 Build/MPB24.65-34-3',
#  'XT1064 Build/MPB24.65-34-3',
#  'ASUS_X008DC Build/NRD90M',
#  'N9137',
#  'SM-J700T Build/NMF26X',
#  'D2406',
#  'SM-N960U Build/M1AJQ',
#  'SM-A320F',
#  'Redmi 4A Build/N2G47H',
#  'NYX_A1',
#  'SAMSUNG SM-J737T Build/R16NW',
#  'SM-G935T Build/NRD90M',
#  'Moto G Play Build/MPIS24.241-15.3-26',
#  'SM-J500FN',
#  'FRD-L04 Build/HUAWEIFRD-L04',
#  'SM-J500F',
#  'SAMSUNG SM-G610M Build/NRD90M',
#  'Z983 Build/NMF26F',
#  'SAMSUNG-SM-G530AZ Build/LMY48B',
#  'LG-LS998',
#  'Moto G (5) Build/NPP25.137-15',
#  'F3111 Build/33.3.A.1.115',
#  'SAMSUNG SM-G965U1 Build/R16NW',
#  'SAMSUNG SM-J510MN Build/NMF26X',
#  'HTC U11 Build/OPR6.170623.013',
#  'G8141 Build/47.1.A.12.270',
#  'rv:50.0',
#  'MYA-L23',
#  'LG-M150',
#  'ONEPLUS A5000 Build/NMF26X',
#  'SAMSUNG SM-P580 Build/NRD90M',
#  '5095I Build/MRA58K',
#  'SAMSUNG SM-J500M Build/MMB29M',
#  'Infinit MX Build/NRD90M',
#  'AX821 Build/MRA58K',
#  'F80 PIABELLA Build/MRA58K',
#  'KEMPLER_TV',
#  'Moto C Build/NRD90M.054',
#  'breeze',
#  'RNE-L21 Build/HUAWEIRNE-L21',
#  'NX16A11264',
#  'PSPC550 Build/LMY47D',
#  'LG-H873 Build/NRD90U',
#  'XT1097',
#  'M4 SS4457 Build/MRA58K',
#  'MYA-L03 Build/HUAWEIMYA-L03',
#  'STELLAR',
#  'Lenovo PB2-670Y Build/MRA58K',
#  'G3223 Build/48.1.A.2.50',
#  'P5026A',
#  'LG-K371',
#  'SAMSUNG SM-G900A Build/MMB29M',
#  'LG-H812',
#  'LGMS550 Build/MXB48T',
#  'ASUS_Z01HD',
#  'TA-1021 Build/OPR1.170623.026',
#  'SM-J327T Build/NRD90M',
#  'SAMSUNG-SGH-I337',
#  'Polaroid',
#  'E6653 Build/32.4.A.1.54',
#  'D6603 Build/23.5.A.1.291',
#  'Moto Z2 Play Build/NPSS26.118-19-4',
#  'SGP621 Build/23.5.A.1.291',
#  'SM-T530 Build/LRX22G',
#  'SAMSUNG-SM-T677A',
#  'hi6210sft Build/MRA58K',
#  'AX921 Build/MRA58K',
#  'Moto Z2 Play Build/OPSS27.76-12-25-7',
#  'SM-G930W8 Build/R16NW',
#  'SM-T110 Build/JDQ39',
#  'rv:38.0',
#  ...]

# %% [markdown]
# Samsung (SAMSUNG, SM)
# LG
# Google (Pixel, Nexus)
# Huawei
# Apple (iOS)
# Motorola (Moto)
# Lenovo
# HTC
# ASUS
# Nokia
# etc.

# %%
# Map device name to its brand name.

device = {'SAMSUNG': 'Samsung', 'SM': 'Samsung', 'LG': 'LG', 'Pixel': 'Google', 'Nexus': 'Google', 
          'HUAWEI': 'Huawei', 'iOS': 'Apple', 'Moto': 'Motorola', 'Lenovo': 'Lenovo', 
           'HTC':'HTC', 'ASUS':'ASUS', 'Nokia': 'Nokia'}

# %%
device
# Out:
# {'SAMSUNG': 'Samsung',
#  'SM': 'Samsung',
#  'LG': 'LG',
#  'Pixel': 'Google',
#  'Nexus': 'Google',
#  'HUAWEI': 'Huawei',
#  'iOS': 'Apple',
#  'Moto': 'Motorola',
#  'Lenovo': 'Lenovo',
#  'HTC': 'HTC',
#  'ASUS': 'ASUS',
#  'Nokia': 'Nokia'}

# %%
train['DInfo'] = train['DeviceInfo'].apply(lambda x : train['DInfo'] = v if k in x else 'etc.' for k, v in device.items())

# %%
train_info = train_dum.replace({'(.+?)SAMSUNG(.+)': 'Samsung', '(.+?)SM(.+)': 'Samsung', '(.+?)LG(.+)': 'LG', 
                                '(.+?)Pixel(.+)': '(.+?)Google', 'Nexus(.+)': 'Google', 
          '(.+?)HUAWEI(.+)': 'Huawei', '(.+?)iOS(.+)': 'Apple', '(.+?)Moto(.+)': 'Motorola', 
                                '(.+?)Lenovo(.+)': 'Lenovo', 
           '(.+?)HTC(.+)':'HTC', '(.+?)ASUS(.+)':'ASUS', '(.+?)Nokia(.+)': 'Nokia'}, regex = True)

# %%
train_info.DeviceInfo.nunique()
# Out:
# 1553

# %%
train_dum.DeviceInfo.nunique()
# Out:
# 1786

# %%
train_info.head(100)
# Out:
#     TransactionID            DeviceInfo  DeviceType_desktop  \
# 0         2987004               Samsung                   0
# 1         2987008            iOS Device                   0
# 2         2987010               Windows                   1
# 3         2987011                   NaN                   1
# 4         2987016                 MacOS                   1
# ..            ...                   ...                 ...
# 95        2987390                 MacOS                   1
# 96        2987398  LG-K500 Build/MMB29M                   0
# 97        2987404            iOS Device                   0
# 98        2987405                   NaN                   0
# 99        2987406            iOS Device                   0
#
#     DeviceType_missing  DeviceType_mobile
# 0                    0                  1
# 1                    0                  1
# 2                    0                  0
# 3                    0                  0
# 4                    0                  0
# ..                 ...                ...
# 95                   0                  0
# 96                   0                  1
# 97                   0                  1
# 98                   0                  1
# 99                   0                  1
#
# [100 rows x 5 columns]

# %%
train.head()
# Out:
#    TransactionID DeviceType                     DeviceInfo
# 0        2987004     mobile  SAMSUNG SM-G892A Build/NRD90M
# 1        2987008     mobile                     iOS Device
# 2        2987010    desktop                        Windows
# 3        2987011    desktop                            NaN
# 4        2987016    desktop                          MacOS

# %%
train.set_index('TransactionID')
# Out:
#               DeviceType                          DeviceInfo
# TransactionID
# 2987004           mobile       SAMSUNG SM-G892A Build/NRD90M
# 2987008           mobile                          iOS Device
# 2987010          desktop                             Windows
# 2987011          desktop                                 NaN
# 2987016          desktop                               MacOS
# ...                  ...                                 ...
# 3577521           mobile             F3111 Build/33.3.A.1.97
# 3577526           mobile                 A574BL Build/NMF26F
# 3577529           mobile  Moto E (4) Plus Build/NMA26.42-152
# 3577531          desktop                               MacOS
# 3577534           mobile         RNE-L03 Build/HUAWEIRNE-L03
#
# [144233 rows x 2 columns]

# %%
i = train[train['DeviceType'] == 'NaN'].index

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-9eee990c02fa> in <module>
# ----> 1 i.head()
#
# AttributeError: 'Int64Index' object has no attribute 'head'
