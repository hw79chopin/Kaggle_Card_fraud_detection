# %%
import pandas as pd
import pandas_profiling
import numpy as np
import seaborn as sns

id_train = pd.read_csv('ieee-fraud-detection/train_identity.csv', engine='python')

# %%
id_train.head(3)
# Out:
#    TransactionID  id_01     id_02  id_03  id_04  id_05  id_06  id_07  id_08  \
# 0        2987004    0.0   70787.0    NaN    NaN    NaN    NaN    NaN    NaN
# 1        2987008   -5.0   98945.0    NaN    NaN    0.0   -5.0    NaN    NaN
# 2        2987010   -5.0  191631.0    0.0    0.0    0.0    0.0    NaN    NaN
#
#    id_09  ...                id_31  id_32      id_33           id_34  id_35  \
# 0    NaN  ...  samsung browser 6.2   32.0  2220x1080  match_status:2      T
# 1    NaN  ...   mobile safari 11.0   32.0   1334x750  match_status:1      T
# 2    0.0  ...          chrome 62.0    NaN        NaN             NaN      F
#
#   id_36 id_37  id_38  DeviceType                     DeviceInfo
# 0     F     T      T      mobile  SAMSUNG SM-G892A Build/NRD90M
# 1     F     F      T      mobile                     iOS Device
# 2     F     T      T     desktop                        Windows
#
# [3 rows x 41 columns]

# %%
id_train.shape
# Out:
# (144233, 41)

# %%
id_train.columns
# Out:
# Index(['TransactionID', 'id_01', 'id_02', 'id_03', 'id_04', 'id_05', 'id_06',
#        'id_07', 'id_08', 'id_09', 'id_10', 'id_11', 'id_12', 'id_13', 'id_14',
#        'id_15', 'id_16', 'id_17', 'id_18', 'id_19', 'id_20', 'id_21', 'id_22',
#        'id_23', 'id_24', 'id_25', 'id_26', 'id_27', 'id_28', 'id_29', 'id_30',
#        'id_31', 'id_32', 'id_33', 'id_34', 'id_35', 'id_36', 'id_37', 'id_38',
#        'DeviceType', 'DeviceInfo'],
#       dtype='object')

# %%
id_train.isnull().sum()
# Out:
# TransactionID         0
# id_01                 0
# id_02              3361
# id_03             77909
# id_04             77909
# id_05              7368
# id_06              7368
# id_07            139078
# id_08            139078
# id_09             69307
# id_10             69307
# id_11              3255
# id_12                 0
# id_13             16913
# id_14             64189
# id_15              3248
# id_16             14893
# id_17              4864
# id_18             99120
# id_19              4915
# id_20              4972
# id_21            139074
# id_22            139064
# id_23            139064
# id_24            139486
# id_25            139101
# id_26            139070
# id_27            139064
# id_28              3255
# id_29              3255
# id_30             66668
# id_31              3951
# id_32             66647
# id_33             70944
# id_34             66428
# id_35              3248
# id_36              3248
# id_37              3248
# ...

# %%
id_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144233 entries, 0 to 144232
# Data columns (total 41 columns):
# TransactionID    144233 non-null int64
# id_01            144233 non-null float64
# id_02            140872 non-null float64
# id_03            66324 non-null float64
# id_04            66324 non-null float64
# id_05            136865 non-null float64
# id_06            136865 non-null float64
# id_07            5155 non-null float64
# id_08            5155 non-null float64
# id_09            74926 non-null float64
# id_10            74926 non-null float64
# id_11            140978 non-null float64
# id_12            144233 non-null object
# id_13            127320 non-null float64
# id_14            80044 non-null float64
# id_15            140985 non-null object
# id_16            129340 non-null object
# id_17            139369 non-null float64
# id_18            45113 non-null float64
# id_19            139318 non-null float64
# ...

# %%
id_train.describe()
# Out:
#        TransactionID          id_01          id_02         id_03  \
# count   1.442330e+05  144233.000000  140872.000000  66324.000000
# mean    3.236329e+06     -10.170502  174716.584708      0.060189
# std     1.788496e+05      14.347949  159651.816856      0.598231
# min     2.987004e+06    -100.000000       1.000000    -13.000000
# 25%     3.077142e+06     -10.000000   67992.000000      0.000000
# 50%     3.198818e+06      -5.000000  125800.500000      0.000000
# 75%     3.392923e+06      -5.000000  228749.000000      0.000000
# max     3.577534e+06       0.000000  999595.000000     10.000000
#
#               id_04          id_05          id_06        id_07        id_08  \
# count  66324.000000  136865.000000  136865.000000  5155.000000  5155.000000
# mean      -0.058938       1.615585      -6.698710    13.285354   -38.600388
# std        0.701015       5.249856      16.491104    11.384207    26.084899
# ...

# %%
# convert the datatype 'object' to 'category'
clst = list(id_train.select_dtypes(include = 'object').columns)

for c in clst:
    id_train[c] = id_train[c].astype('category')

# %%
id_train.select_dtypes(include = 'category')
# Out:
#            id_12  id_15     id_16 id_23 id_27  id_28     id_29  \
# 0       NotFound    New  NotFound   NaN   NaN    New  NotFound
# 1       NotFound    New  NotFound   NaN   NaN    New  NotFound
# 2       NotFound  Found     Found   NaN   NaN  Found     Found
# 3       NotFound    New  NotFound   NaN   NaN    New  NotFound
# 4       NotFound  Found     Found   NaN   NaN  Found     Found
# ...          ...    ...       ...   ...   ...    ...       ...
# 144228  NotFound  Found     Found   NaN   NaN  Found     Found
# 144229  NotFound    New  NotFound   NaN   NaN    New  NotFound
# 144230  NotFound    New  NotFound   NaN   NaN    New  NotFound
# 144231  NotFound  Found     Found   NaN   NaN  Found     Found
# 144232  NotFound    New  NotFound   NaN   NaN    New  NotFound
#
#                    id_30                    id_31      id_33           id_34  \
# 0            Android 7.0      samsung browser 6.2  2220x1080  match_status:2
# ...

# %%
id_train.describe(include=['category'])
# Out:
#            id_12   id_15   id_16                 id_23  id_27   id_28   id_29  \
# count     144233  140985  129340                  5169   5169  140978  140978
# unique         2       3       2                     3      2       2       2
# top     NotFound   Found   Found  IP_PROXY:TRANSPARENT  Found   Found   Found
# freq      123025   67728   66324                  3489   5155   76232   74926
#
#              id_30        id_31      id_33           id_34   id_35   id_36  \
# count        77565       140282      73289           77805  140985  140985
# unique          75          130        260               4       2       2
# top     Windows 10  chrome 63.0  1920x1080  match_status:2       T       F
# freq         21155        22000      16874           60011   77814  134066
#
#          id_37   id_38 DeviceType DeviceInfo
# count   140985  140985     140810     118666
# unique       2       2          2       1786
# top          T       F    desktop    Windows
# ...

# %%
id_train.select_dtypes(exclude = 'category').drop('TransactionID', axis = 1, inplace = False).corr()
# Out:
#           id_01     id_02     id_03     id_04     id_05     id_06     id_07  \
# id_01  1.000000 -0.142064  0.019511  0.039660  0.009666  0.201637  0.114280
# id_02 -0.142064  1.000000 -0.020115  0.000605 -0.101547 -0.047041 -0.000758
# id_03  0.019511 -0.020115  1.000000  0.342178  0.034280  0.056069  0.021234
# id_04  0.039660  0.000605  0.342178  1.000000 -0.029264  0.081269  0.043020
# id_05  0.009666 -0.101547  0.034280 -0.029264  1.000000 -0.291584  0.219281
# id_06  0.201637 -0.047041  0.056069  0.081269 -0.291584  1.000000 -0.028910
# id_07  0.114280 -0.000758  0.021234  0.043020  0.219281 -0.028910  1.000000
# id_08  0.099587  0.005047  0.056737  0.051455  0.008645  0.326691 -0.094086
# id_09  0.029174 -0.020656  0.710782  0.251470  0.085882  0.079989  0.082746
# id_10  0.050737  0.017490  0.112707  0.337323 -0.070985  0.222372  0.071988
# id_11  0.014453  0.053775 -0.005976 -0.001119 -0.043037  0.020841  0.028578
# ...
