# %%
from tensorflow.keras.preprocessing import image

# %%
PATH = "image/"
image.load_img(PATH + "Imputation.png", target_size=(300, 700))
# Out:
# <PIL.Image.Image image mode=RGB size=700x300 at 0x21BEBE6E7F0>

# %% [markdown]
# # 자료 설명
#     - 검은색이 median으로 imputation 했을 때의 isFraud와의 상관관계
#     - 빨간은 mean으로 했을 때
#     - median으로 imputation 했을 때 가장 mean보다 더 잘 유지 됨. 그림으로만 봐도 되고 수치로 봐도 그럼.
#     - 다른 imputation method를 안 쓴 건, isfraud 말고 impuation의 준거가 될 적당한 column이 없다고 판단 했기 때문임. 알다시피 isfraud 열은 test set에서는 사용불가
#     - 기회가 된다면 모든 열 들에 대해 imputation해 보고 싶긴 함.

# %%
PATH = "image/"
image.load_img(PATH + "PCA_ID.png", target_size=(700, 700))
# Out:
# <PIL.Image.Image image mode=RGB size=700x700 at 0x21BF0636198>

# %% [markdown]
# # 자료 설명
#     - ID 열을 PCA기법으로 차원축소함
#     - 위 그림은 분산의 보존비율을 열 개수(0~12, 12개가 원본)의 변동에 따라 표로 보여준 것
#     - 기울기가 줄어드는 영역이 상당히 늦게 나타남. 유의미한 열들 중 독립적인 열들만 추출했으므로 당연한 결과

# %%
PATH = "image/"
image.load_img(PATH + "PCA_V_COL.png", target_size=(700, 700))
# Out:
# <PIL.Image.Image image mode=RGB size=700x700 at 0x21BF06363C8>

# %% [markdown]
# # 자료 설명
#     - 위와 마찬가지. V 열에 대한 것
#     - 다만 기울기가 줄어드는 영역이 초반에 나타남. 모든 V열을 포함한 결과이므로 중첩되는 영역이 크다는 것을 알 수 있음

# %%
PATH = "image/"
image.load_img(PATH + "whatisPCA.png", target_size=(1000, 1000))
# Out:
# <PIL.Image.Image image mode=RGB size=1000x1000 at 0x21BF0636518>

# %% [markdown]
# # PCA가 무엇이고 분산은 무엇인지 궁금하면 읽어보시길
